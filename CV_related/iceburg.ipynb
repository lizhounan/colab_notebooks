# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_json('train.json')
label = train['is_iceburg']
train['inc_angle'] = pd.to_numeric(train['inc_angle'], errors='coerce')  # there is NA
train['inc_angle'].fillna(method='pad', inplace=True)
train_angle = train['inc_angle']

# %%
X_band_1=np.extend_dims(np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]]),
                        axis=-1)
X_band_2=np.extend_dims(np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]]),
                        axis=-1)
X_band_3=(X_band_1+X_band_2)/2
#X_band_3=np.array([np.full((75, 75), angel).astype(np.float32) for angel in train["inc_angle"]])
X_train = np.concatenate([X_band_1, X_band_2, X_band_3, axis=-1)
